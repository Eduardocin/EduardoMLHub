# %%
train_df = pd.read_csv('C:/Users/Eduar/OneDrive/Documentos/GitHub/MachineLearning/Deeplearning/sign_mnist_train.csv')
test_df = pd.read_csv('C:/Users/Eduar/OneDrive/Documentos/GitHub/MachineLearning/Deeplearning/sign_mnist_valid.csv')

# %%
import pandas as pd

# %%
train_df.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     12     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# ...

# %%
y_train = train_df['label']
y_test = test_df['label']
del train_df['label']
del test_df['label']

# %%
x_train = train_df.values
x_valid = test_df.values

# %%
import matplotlib.pyplot as plt
import pandas as pd


plt.figure(figsize=(60, 60))

num_images = 20
for i in range(num_images):
    row = x_train[i]
    label = y_train[i]

    image = row.reshape(28, 28)
    plt.subplot(1, num_images, i + 1)
    plt.title(label, fontdict={'fontsize': 30})
    plt.axis('off')
    plt.imshow(image, cmap='gray')

plt.show()

# %%
x_train.min(), x_train.max()
# Out:
# (0, 255)

# %%
x_train_normalized = x_train / 255.0
x_valid_normalized = x_valid / 255.0

# %%
import tensorflow.keras as keras
num_classes = 26
