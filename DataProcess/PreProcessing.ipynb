# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C:\\Users\\Eduar\\OneDrive\\Documentos\\GitHub\\MachineLearning\\DataProcess\\Folds5x2_pp.xlsx")

# %%
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
x = df.iloc[:,0:4].values
x[:,0:1]
# Out:
# array([[14.96],
#        [25.18],
#        [ 5.11],
#        ...,
#        [31.32],
#        [24.48],
#        [21.6 ]])

# %%
plt.hist(x[:,2:3])
# Out:
# (array([  16.,  101.,  554., 1699., 2530., 2212., 1586.,  579.,  212.,
#           79.]),
#  array([ 992.89 ,  996.931, 1000.972, 1005.013, 1009.054, 1013.095,
#         1017.136, 1021.177, 1025.218, 1029.259, 1033.3  ]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()

x[:,2:3] = scale.fit_transform(x[:,2:3])

# %%
plt.hist(x[:,2:3])
# Out:
# (array([  16.,  101.,  554., 1699., 2530., 2212., 1586.,  579.,  212.,
#           79.]),
#  array([-3.43001929, -2.74954137, -2.06906345, -1.38858553, -0.70810761,
#         -0.02762969,  0.65284823,  1.33332615,  2.01380407,  2.69428199,
#          3.37475991]),
#  <BarContainer object of 10 artists>)
